# %% [markdown]
# Import from a notebook that imports adjacent notebooks from the same Gist (local imports in a remote notebook):

# %%
from gist._1288bff2f9e05394a94312010da267bb import *
# Out:
# find_spec: gist._1288bff2f9e05394a94312010da267bb ['/Users/ryan/c/ur/gist'] None (commit? None)
# find_spec: gitdb_speedups None None (commit? None)
# find_spec: gitdb_speedups None None (commit? None)
# find_spec: gitdb_speedups None None (commit? None)
# Meta.__new__(<class 'pclass.dircache.Meta'>, Commit, (), {'__module__': '_gist', '__qualname__': 'Commit', '__init__': <function Commit.__init__ at 0x10d40bc10>, 'url': <property object at 0x10d406a40>, 'user': <property object at 0x10d406a90>, 'author': <property object at 0x10d406ae0>, 'commit': <property object at 0x10d406b30>, 'tree': <property object at 0x10d406b80>, 'blobs': <property object at 0x10d406bd0>, 'files': <property object at 0x10d406c20>, 'files_dict': <property object at 0x10d406c70>, 'file_bases_dict': <property object at 0x10d406cc0>, 'xml': <pclass.field.DirectField object at 0x10d247490>, 'load_xml': None, 'fragments': <pclass.field.Field object at 0x10d247520>})
# cache_root=None
# Class cache dir: .objs/Commit
# Checking: __module__: _gist
# __module__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e5e0>, name='__module__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__module__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __module__
# Checking: __qualname__: Commit
# __qualname__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e9d0>, name='__qualname__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__qualname__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __qualname__
# Checking: __init__: <function Commit.__init__ at 0x10d40bc10>
# __init__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e700>, name='__init__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__init__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __init__
# Checking: url: <property object at 0x10d406a40>
# url: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42ea60>, name='url') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='url'">), ('_kw', <Parameter "**_kw">)])
# Skipping: url
# Checking: user: <property object at 0x10d406a90>
# user: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42edc0>, name='user') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='user'">), ('_kw', <Parameter "**_kw">)])
# Skipping: user
# Checking: author: <property object at 0x10d406ae0>
# author: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d410160>, name='author') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='author'">), ('_kw', <Parameter "**_kw">)])
# Skipping: author
# Checking: commit: <property object at 0x10d406b30>
# commit: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42ee50>, name='commit') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='commit'">), ('_kw', <Parameter "**_kw">)])
# Skipping: commit
# Checking: tree: <property object at 0x10d406b80>
# tree: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e700>, name='tree') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='tree'">), ('_kw', <Parameter "**_kw">)])
# Skipping: tree
# Checking: blobs: <property object at 0x10d406bd0>
# blobs: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e9d0>, name='blobs') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='blobs'">), ('_kw', <Parameter "**_kw">)])
# Skipping: blobs
# Checking: files: <property object at 0x10d406c20>
# files: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e310>, name='files') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='files'">), ('_kw', <Parameter "**_kw">)])
# Skipping: files
# Checking: files_dict: <property object at 0x10d406c70>
# files_dict: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42ec10>, name='files_dict') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='files_dict'">), ('_kw', <Parameter "**_kw">)])
# Skipping: files_dict
# Checking: file_bases_dict: <property object at 0x10d406cc0>
# file_bases_dict: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e940>, name='file_bases_dict') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='file_bases_dict'">), ('_kw', <Parameter "**_kw">)])
# Skipping: file_bases_dict
# Checking: xml: <pclass.field.DirectField object at 0x10d247490>
# xml: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d4280d0>, name='xml') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='xml'">), ('_kw', <Parameter "**_kw">)])
# field: xml -> <pclass.field.DirectField object at 0x10d247490>
# Setting method: xml: <property object at 0x10d416130>
# Checking: load_xml: None
# load_xml: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d4285e0>, name='load_xml') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='load_xml'">), ('_kw', <Parameter "**_kw">)])
# Skipping: load_xml
# Checking: fragments: <pclass.field.Field object at 0x10d247520>
# fragments: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428940>, name='fragments') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='fragments'">), ('_kw', <Parameter "**_kw">)])
# field: fragments -> <pclass.field.Field object at 0x10d247520>
# Setting method: fragments: <property object at 0x10d4162c0>
# Fields: ['xml', 'fragments']
# returning <class '_gist.Commit'>: {'__module__': '_gist', '__qualname__': 'Commit', '__init__': <function Commit.__init__ at 0x10d42eee0>, 'url': <property object at 0x10d406a40>, 'user': <property object at 0x10d406a90>, 'author': <property object at 0x10d406ae0>, 'commit': <property object at 0x10d406b30>, 'tree': <property object at 0x10d406b80>, 'blobs': <property object at 0x10d406bd0>, 'files': <property object at 0x10d406c20>, 'files_dict': <property object at 0x10d406c70>, 'file_bases_dict': <property object at 0x10d406cc0>, 'xml': <property object at 0x10d416130>, 'load_xml': None, 'fragments': <property object at 0x10d4162c0>, '__str__': <function Meta.__new__.<locals>.__str__ at 0x10d42ea60>, '__repr__': <function Meta.__new__.<locals>.__str__ at 0x10d42ea60>}
# Meta.__new__(<class 'pclass.dircache.Meta'>, Gist, (), {'__module__': '_gist', '__qualname__': 'Gist', 'WWW_URL_PATH_REGEX': '^(?:/(?P<user>[A-Za-z0-9_\\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\\-]+))?$', 'RAW_URL_PATH_REGEX': '^/(?P<user>[A-Za-z0-9_\\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\\-\\.]+))?$', 'URL_PATH_REGEXS': ['^(?:/(?P<user>[A-Za-z0-9_\\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\\-]+))?$', '^/(?P<user>[A-Za-z0-9_\\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\\-\\.]+))?$'], 'ID_LEN': 32, '__init__': <function Gist.__init__ at 0x10d42e310>, 'from_url': <classmethod object at 0x10d404f10>, 'parse_url': <classmethod object at 0x10d4045e0>, 'parse_url_path': <classmethod object at 0x10d4046a0>, 'from_url_path': <classmethod object at 0x10d404ca0>, 'from_dict': <classmethod object at 0x10d404910>, 'git_url': <property object at 0x10d416360>, 'url': <property object at 0x10d4163b0>, 'module_name': <property object at 0x10d416400>, 'user': <pclass.field.Field object at 0x10d404f70>, 'xml': <property object at 0x10d416450>, 'clone': <pclass.field.DirectField object at 0x10d404f40>, 'commit': <property object at 0x10d4164a0>, 'clone_dir': <property object at 0x10d4164f0>})
# cache_root=None
# Class cache dir: .objs/Gist
# Checking: __module__: _gist
# __module__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e820>, name='__module__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__module__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __module__
# Checking: __qualname__: Gist
# __qualname__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d4280d0>, name='__qualname__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__qualname__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __qualname__
# Checking: WWW_URL_PATH_REGEX: ^(?:/(?P<user>[A-Za-z0-9_\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\-]+))?$
# WWW_URL_PATH_REGEX: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42eca0>, name='WWW_URL_PATH_REGEX') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='WWW_URL_PATH_REGEX'">), ('_kw', <Parameter "**_kw">)])
# Skipping: WWW_URL_PATH_REGEX
# Checking: RAW_URL_PATH_REGEX: ^/(?P<user>[A-Za-z0-9_\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\-\.]+))?$
# RAW_URL_PATH_REGEX: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42ef70>, name='RAW_URL_PATH_REGEX') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='RAW_URL_PATH_REGEX'">), ('_kw', <Parameter "**_kw">)])
# Skipping: RAW_URL_PATH_REGEX
# Checking: URL_PATH_REGEXS: ['^(?:/(?P<user>[A-Za-z0-9_\\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\\-]+))?$', '^/(?P<user>[A-Za-z0-9_\\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\\-\\.]+))?$']
# URL_PATH_REGEXS: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428670>, name='URL_PATH_REGEXS') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='URL_PATH_REGEXS'">), ('_kw', <Parameter "**_kw">)])
# Skipping: URL_PATH_REGEXS
# Checking: ID_LEN: 32
# ID_LEN: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428040>, name='ID_LEN') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='ID_LEN'">), ('_kw', <Parameter "**_kw">)])
# Skipping: ID_LEN
# Checking: __init__: <function Gist.__init__ at 0x10d42e310>
# __init__: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428d30>, name='__init__') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='__init__'">), ('_kw', <Parameter "**_kw">)])
# Skipping: __init__
# Checking: from_url: <classmethod object at 0x10d404f10>
# from_url: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d41d0d0>, name='from_url') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='from_url'">), ('_kw', <Parameter "**_kw">)])
# Skipping: from_url
# Checking: parse_url: <classmethod object at 0x10d4045e0>
# parse_url: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d41d430>, name='parse_url') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='parse_url'">), ('_kw', <Parameter "**_kw">)])
# Skipping: parse_url
# Checking: parse_url_path: <classmethod object at 0x10d4046a0>
# parse_url_path: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d41d790>, name='parse_url_path') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='parse_url_path'">), ('_kw', <Parameter "**_kw">)])
# Skipping: parse_url_path
# Checking: from_url_path: <classmethod object at 0x10d404ca0>
# from_url_path: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428e50>, name='from_url_path') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='from_url_path'">), ('_kw', <Parameter "**_kw">)])
# Skipping: from_url_path
# Checking: from_dict: <classmethod object at 0x10d404910>
# from_dict: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428a60>, name='from_dict') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='from_dict'">), ('_kw', <Parameter "**_kw">)])
# Skipping: from_dict
# Checking: git_url: <property object at 0x10d416360>
# git_url: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428700>, name='git_url') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='git_url'">), ('_kw', <Parameter "**_kw">)])
# Skipping: git_url
# Checking: url: <property object at 0x10d4163b0>
# url: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e700>, name='url') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='url'">), ('_kw', <Parameter "**_kw">)])
# Skipping: url
# Checking: module_name: <property object at 0x10d416400>
# module_name: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e8b0>, name='module_name') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='module_name'">), ('_kw', <Parameter "**_kw">)])
# Skipping: module_name
# Checking: user: <pclass.field.Field object at 0x10d404f70>
# user: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d40e1f0>, name='user') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='user'">), ('_kw', <Parameter "**_kw">)])
# field: user -> <pclass.field.Field object at 0x10d404f70>
# Setting method: user: <property object at 0x10d416bd0>
# Checking: xml: <property object at 0x10d416450>
# xml: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d40e700>, name='xml') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='xml'">), ('_kw', <Parameter "**_kw">)])
# Skipping: xml
# Checking: clone: <pclass.field.DirectField object at 0x10d404f40>
# clone: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d40ea60>, name='clone') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='clone'">), ('_kw', <Parameter "**_kw">)])
# field: clone -> <pclass.field.DirectField object at 0x10d404f40>
# Setting method: clone: <property object at 0x10d416c70>
# Checking: commit: <property object at 0x10d4164a0>
# commit: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d42e8b0>, name='commit') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='commit'">), ('_kw', <Parameter "**_kw">)])
# Skipping: commit
# Checking: clone_dir: <property object at 0x10d4164f0>
# clone_dir: bind functools.partial(<function Meta.__new__.<locals>._bind at 0x10d428700>, name='clone_dir') OrderedDict([('fn', <Parameter "fn">), ('name', <Parameter "name='clone_dir'">), ('_kw', <Parameter "**_kw">)])
# Skipping: clone_dir
# Fields: ['user', 'clone']
# returning <class '_gist.Gist'>: {'__module__': '_gist', '__qualname__': 'Gist', 'WWW_URL_PATH_REGEX': '^(?:/(?P<user>[A-Za-z0-9_\\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\\-]+))?$', 'RAW_URL_PATH_REGEX': '^/(?P<user>[A-Za-z0-9_\\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\\-\\.]+))?$', 'URL_PATH_REGEXS': ['^(?:/(?P<user>[A-Za-z0-9_\\-]+))?/(?P<id>[a-f0-9]+)(?:/(?P<commit>[a-f0-9]+))?(?:#(?P<fragment>[A-Za-z0-9_\\-]+))?$', '^/(?P<user>[A-Za-z0-9_\\-]+)/(?P<id>[a-f0-9]+)/(?P<raw>raw)(?:/(?P<commit>[a-f0-9]+))?(?:/(?P<file>[A-Za-z0-9_\\-\\.]+))?$'], 'ID_LEN': 32, '__init__': <function Gist.__init__ at 0x10d428a60>, 'from_url': <classmethod object at 0x10d404f10>, 'parse_url': <classmethod object at 0x10d4045e0>, 'parse_url_path': <classmethod object at 0x10d4046a0>, 'from_url_path': <classmethod object at 0x10d404ca0>, 'from_dict': <classmethod object at 0x10d404910>, 'git_url': <property object at 0x10d416360>, 'url': <property object at 0x10d4163b0>, 'module_name': <property object at 0x10d416400>, 'user': <property object at 0x10d416bd0>, 'xml': <property object at 0x10d416450>, 'clone': <property object at 0x10d416c70>, 'commit': <property object at 0x10d4164a0>, 'clone_dir': <property object at 0x10d4164f0>, '__str__': <function Meta.__new__.<locals>.__str__ at 0x10d428790>, '__repr__': <function Meta.__new__.<locals>.__str__ at 0x10d428790>}
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb, clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) ([]; None)
# Creating package spec from https://gist.github.com/1288bff2f9e05394a94312010da267bb (https://gist.github.com/1288bff2f9e05394a94312010da267bb)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.github.com/1288bff2f9e05394a94312010da267bb', submodule_search_locations=['/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone'])
# Installing module gist._1288bff2f9e05394a94312010da267bb: <module 'gist._1288bff2f9e05394a94312010da267bb' (https://gist.github.com/1288bff2f9e05394a94312010da267bb)>
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb' (https://gist.github.com/1288bff2f9e05394a94312010da267bb)>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.a_b None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['a_b']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/a_b.ipynb (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/a_b.ipynb)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module a_b (gist._1288bff2f9e05394a94312010da267bb.a_b)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.a_b', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/a_b.ipynb')
# Installing module gist._1288bff2f9e05394a94312010da267bb.a_b: <module 'gist._1288bff2f9e05394a94312010da267bb.a_b' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/a_b.ipynb)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.c None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['c']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/c.ipynb (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/c.ipynb)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module c (gist._1288bff2f9e05394a94312010da267bb.c)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.c', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/c.ipynb')
# Installing module gist._1288bff2f9e05394a94312010da267bb.c: <module 'gist._1288bff2f9e05394a94312010da267bb.c' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/c.ipynb)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.d None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['d']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/d.py (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/d.py)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module d (gist._1288bff2f9e05394a94312010da267bb.d)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.d', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/d.py')
# Installing module gist._1288bff2f9e05394a94312010da267bb.d: <module 'gist._1288bff2f9e05394a94312010da267bb.d' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/d.py)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.nb_import_nb None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['nb_import_nb']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_nb.ipynb (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_nb.ipynb)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module nb_import_nb (gist._1288bff2f9e05394a94312010da267bb.nb_import_nb)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.nb_import_nb', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_nb.ipynb')
# Installing module gist._1288bff2f9e05394a94312010da267bb.nb_import_nb: <module 'gist._1288bff2f9e05394a94312010da267bb.nb_import_nb' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_nb.ipynb)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.nb_import_py None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['nb_import_py']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_py.ipynb (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_py.ipynb)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module nb_import_py (gist._1288bff2f9e05394a94312010da267bb.nb_import_py)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.nb_import_py', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_py.ipynb')
# Installing module gist._1288bff2f9e05394a94312010da267bb.nb_import_py: <module 'gist._1288bff2f9e05394a94312010da267bb.nb_import_py' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_py.ipynb)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.py_import_nb None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['py_import_nb']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_nb.py (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_nb.py)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module py_import_nb (gist._1288bff2f9e05394a94312010da267bb.py_import_nb)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.py_import_nb', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_nb.py')
# Installing module gist._1288bff2f9e05394a94312010da267bb.py_import_nb: <module 'gist._1288bff2f9e05394a94312010da267bb.py_import_nb' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_nb.py)>
# find_spec: gist._1288bff2f9e05394a94312010da267bb.py_import_py None None (commit? 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc)
# Gist 1288bff2f9e05394a94312010da267bb: skip_cache=False
# __init__(self, ('1288bff2f9e05394a94312010da267bb',), {'_skip_cache': False})
# Setting cache id id=1288bff2f9e05394a94312010da267bb
# Set _dir=.objs/Gist/1288bff2f9e05394a94312010da267bb for id 1288bff2f9e05394a94312010da267bb
# Done with injected __init__
# __init__(self, ('4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc', Gist(id=1288bff2f9e05394a94312010da267bb)), {})
# Setting cache id id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Set _dir=.objs/Commit/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc for id 4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc
# Done with injected __init__
# Building module/pkg for gist Commit(id=4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc) (['py_import_py']; None)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# clone_dir params: OrderedDict([('path', <Parameter "path=None">), ('odbt', <Parameter "odbt=<class 'git.db.GitCmdObjectDB'>">), ('search_parent_directories', <Parameter "search_parent_directories=False">), ('expand_vars', <Parameter "expand_vars=True">)]) for fn <class 'git.repo.base.Repo'>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/clone to <class 'git.repo.base.Repo'>
# clone_dir: calling <class 'git.repo.base.Repo'> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/clone')}
# Loaded attr from cache: _clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# wrapped_fn: user (_user): field <pclass.field.Field object at 0x10d404f70> loader <pclass.loader.Loader object at 0x10d41d820>
# clone_dir params: OrderedDict([('path', <Parameter "path">)]) for fn <function JSONLoader._load at 0x10d23fe50>
# clone_dir adding path .objs/Gist/1288bff2f9e05394a94312010da267bb/user to <function JSONLoader._load at 0x10d23fe50>
# clone_dir: calling <function JSONLoader._load at 0x10d23fe50> with {'path': PosixPath('.objs/Gist/1288bff2f9e05394a94312010da267bb/user')}
# Loaded attr from cache: _user=ryan-williams
# Creating package spec from https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_py.py (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_py.py)
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# Found spec for child module py_import_py (gist._1288bff2f9e05394a94312010da267bb.py_import_py)
# create_module ModuleSpec(name='gist._1288bff2f9e05394a94312010da267bb.py_import_py', loader=<importer.Importer object at 0x10bfd56d0>, origin='https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_py.py')
# Installing module gist._1288bff2f9e05394a94312010da267bb.py_import_py: <module 'gist._1288bff2f9e05394a94312010da267bb.py_import_py' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_py.py)>
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.a_b' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/a_b.ipynb)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.a_b
# exec notebook: a_b.ipynb
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# defs only
# defs only
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.c' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/c.ipynb)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.c
# exec notebook: c.ipynb
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# defs only
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.d' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/d.py)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.d
# exec py: d.py
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.nb_import_nb' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_nb.ipynb)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.nb_import_nb
# exec notebook: nb_import_nb.ipynb
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# defs only
# find_spec: a_b None None (commit? None)
# defs only
# defs only
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.nb_import_py' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/nb_import_py.ipynb)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.nb_import_py
# exec notebook: nb_import_py.ipynb
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# defs only
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.py_import_nb' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_nb.py)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.py_import_nb
# exec py: py_import_nb.py
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>
# exec_module <module 'gist._1288bff2f9e05394a94312010da267bb.py_import_py' (https://gist.githubusercontent.com/ryan-williams/1288bff2f9e05394a94312010da267bb/raw/4cb2c6dc67ffceb540fd41ded4b61a6f72cd57dc/py_import_py.py)>
# Attempt to exec module gist._1288bff2f9e05394a94312010da267bb.py_import_py
# exec py: py_import_py.py
# wrapped_fn: clone (_clone): field <pclass.field.DirectField object at 0x10d404f40>
# Lookup: clone=<git.repo.base.Repo '/Users/ryan/c/ur/.objs/Gist/1288bff2f9e05394a94312010da267bb/clone/.git'>

# %%
nb_import_nb.a_and_b()
# Out:
# 'aaabbb'

# %%
nb_import_py.wrap_py_fn()
# Out:
# 'DDD!yay'
